# %%
import pandas as pd
import folium
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('week6.csv')

# %%
df
# Out:
#         name                                        description   latitude  \
# 0        王道家  <a href="https://twitter.com/oudouyakashiwa?re...  35.863107
# 1    ラーメン二九六  <a href="https://twitter.com/ramen296 ">Twitte...  35.861254
# 2      AKEBI  <a href="https://www.instagram.com/akebimen/?h...  35.860901
# 3  俺の生きる道 柏店  <a href="https://twitter.com/oremichikashiwa?r...  35.855724
# 4  こってりラーメン誉  <a href="https://twitter.com/homare_kashiwa">T...  35.860545
# 5         大勝  <a href="https://twitter.com/ramen_daikatsu">T...  35.854603
# 6     麺処　にし尾  <a href="https://twitter.com/mendokoronishio?r...  35.860291
# 7   三代目てらッちょ  <a href="https://twitter.com/oremichikashiwa?r...  35.860586
#
#     longitude   color
# 0  139.967496    blue
# 1  139.970637  orange
# 2  139.974110     red
# 3  139.971645  orange
# 4  139.969043    blue
# 5  139.973571     red
# 6  139.968346     red
# 7  139.972862    blue

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         8 non-null      object
#  1   description  8 non-null      object
#  2   latitude     8 non-null      float64
#  3   longitude    8 non-null      float64
#  4   color        8 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 452.0+ bytes

# %%
center_lat = df['latitude'].mean()
center_lon = df['longitude'].mean()

print(center_lat,center_lon)
# Out:
# 35.85962647375 139.970963725

# %%
m = folium.Map(location=[center_lat,center_lon], zoom_start=17)

for index, row in df.iterrows():
    latlon = [row['latitude'],row['longitude']]
    folium.Marker(latlon, 
                  popup='<div style="width:50px">'+row['description']+'</div>', 
                  tooltip=row['name'],
                  icon=folium.Icon(color=row['color']
                )).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9409f9566009a22feefced078e53eeb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9409f9566009a22feefced078e53eeb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9409f9566009a22feefced078e53eeb = L.map(
#                 &quot;map_c9409f9566009a22feefced078e53eeb&quot;,
#                 {
#                     center: [35.85962647375, 139.970963725],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b2b28e2a0a6ce85068d422ec05cd22a8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c9409f9566009a22feefced078e53eeb);
#
#
#             var marker_961ed1b9dc9fc5da4c9486736b07109e = L.marker(
#                 [35.86310705, 139.9674962],
#                 {}
#             ).addTo(map_c9409f9566009a22feefced078e53eeb);
#
#
#             var icon_fd7c9e579017995d470f5e3d645547e2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_961ed1b9dc9fc5da4c9486736b07109e.setIcon(icon_fd7c9e579017995d470f5e3d645547e2);
#
#
#         var popup_b9f99735bb0913f4642c8cab05c1344d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0393fd007ed47fcb273752f64912afc4 = $(`&lt;div id=&quot;html_0393fd007ed47fcb273752f64912afc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:50px&quot;&gt;&lt;a href=&quot;https://twitter.com/oudouyakashiwa?ref_src=twsrc%5Egoogle%7Ctwcamp%5Eserp%7Ctwgr%5Eauthor&quot;&gt;Twitter&lt;/a&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_b9f99735bb0913f4642c8cab05c1344d.setContent(html_0393fd007ed47fcb273752f64912afc4);
#
#
#
#         marker_961ed1b9dc9fc5da4c9486736b07109e.bindPopup(popup_b9f99735bb0913f4642c8cab05c1344d)
#         ;
#
#
#
#
#             marker_961ed1b9dc9fc5da4c9486736b07109e.bindTooltip(
#                 `&lt;div&gt;
#                      王道家
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d56c5114f2037a41bf2aa52bb9912c5d = L.marker(
#                 [35.8612544, 139.9706366],
#                 {}
#             ).addTo(map_c9409f9566009a22feefced078e53eeb);
#
#
#             var icon_21cc30ba8ef19c609295c740a13550d1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d56c5114f2037a41bf2aa52bb9912c5d.setIcon(icon_21cc30ba8ef19c609295c740a13550d1);
#
#
#         var popup_bda0161b555f1d2ab44c5bec457b9e18 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea332f845492a3f11d4c20e179a755bc = $(`&lt;div id=&quot;html_ea332f845492a3f11d4c20e179a755bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:50px&quot;&gt;&lt;a href=&quot;https://twitter.com/ramen296 &quot;&gt;Twitter&lt;/a&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_bda0161b555f1d2ab44c5bec457b9e18.setContent(html_ea332f845492a3f11d4c20e179a755bc);
#
#
#
#         marker_d56c5114f2037a41bf2aa52bb9912c5d.bindPopup(popup_bda0161b555f1d2ab44c5bec457b9e18)
#         ;
#
#
#
#
#             marker_d56c5114f2037a41bf2aa52bb9912c5d.bindTooltip(
#                 `&lt;div&gt;
#                      ラーメン二九六
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a7402f9a39ab48e52fd669fe5b2b5869 = L.marker(
#                 [35.86090087, 139.9741098],
#                 {}
#             ).addTo(map_c9409f9566009a22feefced078e53eeb);
#
#
#             var icon_c286cb81fdd911fc281abaf2d4bba2f1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a7402f9a39ab48e52fd669fe5b2b5869.setIcon(icon_c286cb81fdd911fc281abaf2d4bba2f1);
#
#
#         var popup_26ff7b83cc0e8a7ddefe7a021dd4e674 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1bcfcb054d04509055840e4a165a19dd = $(`&lt;div id=&quot;htm
