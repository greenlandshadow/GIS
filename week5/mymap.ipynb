# %%
import folium


kashiwaeki = [35.86238453604905, 139.97089573914457]


m = folium.Map(location=kashiwaeki, zoom_start=15)

folium.CircleMarker(
    location=[35.86238453604905, 139.97089573914457],
    radius=280,
    color='#ffff00',
    fill_color='#ffff00'
).add_to(m)

group_1 = folium.FeatureGroup("その他").add_to(m)
group_2 = folium.FeatureGroup("二郎系").add_to(m)
group_3 = folium.FeatureGroup("中華そば").add_to(m)

name = 'X(Twitter)'
href= 'https://twitter.com/oudouyakashiwa?ref_src=twsrc%5Egoogle%7Ctwcamp%5Eserp%7Ctwgr%5Eauthor'
FORMAT_A_TAG = '<a href="{href}" target="_blank">{name}</a>'
html =FORMAT_A_TAG.format(href=href, name=name)
oudouya=[35.86310705313056, 139.96749619209098]
folium.Marker(oudouya, popup=html, tooltip="王道家 柏店",icon=folium.Icon(color='blue')).add_to(group_1)

name = 'X(Twitter)'
href1= 'https://twitter.com/ramen296'
FORMAT_A_TAG = '<a href="{href}" target="_blank">{name}</a>'
html1 =FORMAT_A_TAG.format(href=href1, name=name)
fukurou=[35.861254398368196, 139.9706365688336]
folium.Marker(fukurou, popup=html1, tooltip="ラーメン二九六",icon=folium.Icon(color='green')).add_to(group_2)

name1 = 'Instagram'
href2= 'https://www.instagram.com/akebimen/?hl=ja'
FORMAT_A_TAG = '<a href="{href}" target="_blank">{name}</a>'
html2 =FORMAT_A_TAG.format(href=href2, name=name1)
akebi=[35.86090086608687, 139.9741098153531]
folium.Marker(akebi, popup=html2, tooltip="AKEBI",icon=folium.Icon(color='red')).add_to(group_3)

name = 'X(Twitter)'
href3= 'https://twitter.com/oremichikashiwa?ref_src=twsrc%5Egoogle%7Ctwcamp%5Eserp%7Ctwgr%5Eauthor'
FORMAT_A_TAG = '<a href="{href}" target="_blank">{name}</a>'
html3 =FORMAT_A_TAG.format(href=href3, name=name)
oremichi=[35.85572449449928, 139.97164485359403]
folium.Marker(oremichi, popup=html3, tooltip="俺の生きる道 柏店",icon=folium.Icon(color='green')).add_to(group_2)

name = 'X(Twitter)'
href4= 'https://twitter.com/homare_kashiwa'
FORMAT_A_TAG = '<a href="{href}" target="_blank">{name}</a>'
html4 =FORMAT_A_TAG.format(href=href4, name=name)
homare=[35.86054457043861, 139.969043470783]
folium.Marker(homare, popup=html4, tooltip="こってりラーメン誉",icon=folium.Icon(color='blue')).add_to(group_1)

name = 'X(Twitter)'
href5= 'https://twitter.com/ramen_daikatsu'
FORMAT_A_TAG = '<a href="{href}" target="_blank">{name}</a>'
html5 =FORMAT_A_TAG.format(href=href5, name=name)
daikatsu=[35.854602772556795, 139.97357127917732]
folium.Marker(daikatsu, popup=html5, tooltip="大勝",icon=folium.Icon(color='red')).add_to(group_3)

name = 'X(Twitter)'
href6= 'https://twitter.com/mendokoronishio?ref_src=twsrc%5Egoogle%7Ctwcamp%5Eserp%7Ctwgr%5Eauthor'
FORMAT_A_TAG = '<a href="{href}" target="_blank">{name}</a>'
html6 =FORMAT_A_TAG.format(href=href6, name=name)
nishio=[35.86029125358195, 139.96834584466]
folium.Marker(nishio, popup=html6, tooltip="麺処　にし尾",icon=folium.Icon(color='red')).add_to(group_3)

name2 = '公式ホームページ'
href7= 'https://twitter.com/oremichikashiwa?ref_src=twsrc%5Egoogle%7Ctwcamp%5Eserp%7Ctwgr%5Eauthor'
FORMAT_A_TAG = '<a href="{href}" target="_blank">{name}</a>'
html7 =FORMAT_A_TAG.format(href=href3, name=name2)
teraccyo=[35.86058639460725, 139.97286167078306]
folium.Marker(teraccyo, popup=html7, tooltip="三代目てらッちょ",icon=folium.Icon(color='blue')).add_to(group_1)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m.save('RamenMap.html')
