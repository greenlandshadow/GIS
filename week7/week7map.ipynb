# %%
import geopandas as gpd
import pandas as pd

# %%
kagawa_ku = gpd.read_file("N03-23_37_230101.geojson")

# %%
kagawa_ku.plot()
# Out:
# <Axes: >

# %%
kagawa_ku.sample(6)
# Out:
#     N03_001  N03_002 N03_003 N03_004 N03_007  \
# 616     香川県      NaN     小豆郡     土庄町   37322
# 723     香川県      NaN     香川郡     直島町   37364
# 518     香川県      NaN     NaN     三豊市   37208
# 697     香川県      NaN     香川郡     直島町   37364
# 53      香川県      NaN     NaN     高松市   37201
# 394     香川県      NaN     NaN    さぬき市   37206
#
#                                               geometry
# 616  POLYGON ((134.16213 34.53208, 134.16211 34.532...
# 723  POLYGON ((133.97795 34.50420, 133.97798 34.504...
# 518  POLYGON ((133.60948 34.22409, 133.60947 34.224...
# 697  POLYGON ((134.00435 34.47318, 134.00438 34.473...
# 53   POLYGON ((134.10149 34.40456, 134.10148 34.404...
# 394  POLYGON ((134.21129 34.36901, 134.21129 34.369...

# %%
kagawa_ku.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N03_001   750 non-null    object
#  1   N03_002   0 non-null      float64
#  2   N03_003   175 non-null    object
#  3   N03_004   750 non-null    object
#  4   N03_007   750 non-null    object
#  5   geometry  750 non-null    geometry
# dtypes: float64(1), geometry(1), object(4)
# memory usage: 35.3+ KB

# %%
kagawa_pop = pd.read_csv('kagawa.csv')

# %%
kagawa_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028 entries, 0 to 1027
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   KEY_CODE  1028 non-null   int64
#  1   HYOSYO    1028 non-null   int64
#  2   CITYNAME  1028 non-null   object
#  3   NAME      1006 non-null   object
#  4   HTKSYORI  1028 non-null   int64
#  5   HTKSAKI   0 non-null      float64
#  6   GASSAN    0 non-null      float64
#  7   人口総数      1028 non-null   object
#  8   男         1028 non-null   object
#  9   女         1028 non-null   object
#  10  世帯総数      1028 non-null   object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 88.5+ KB

# %%
kagawa_pop.sample(6)
# Out:
#         KEY_CODE  HYOSYO CITYNAME    NAME  HTKSYORI  HTKSAKI  GASSAN  人口総数  \
# 21     372010130       2      高松市     片原町         0      NaN     NaN   260
# 790    372080320       2      三豊市    詫間町箱         0      NaN     NaN   209
# 93     372010420       2      高松市     中野町         0      NaN     NaN  1384
# 609  37205001205       4     観音寺市  坂本町五丁目         0      NaN     NaN   387
# 302    372020240       2      丸亀市     城南町         0      NaN     NaN   360
# 631    372050017       3     観音寺市      栄町         0      NaN     NaN   221
#
#        男    女 世帯総数
# 21   120  140  140
# 790  103  106   90
# 93   697  687  844
# 609  183  204  171
# 302  157  203  165
# 631  111  110   71

# %%
kagawa_ku.rename(columns={'N03_007':'KEY_CODE'},inplace=True)

# %%
kagawa_ku
# Out:
#     N03_001  N03_002 N03_003 N03_004 KEY_CODE  \
# 0       香川県      NaN     NaN     高松市    37201
# 1       香川県      NaN     NaN     高松市    37201
# 2       香川県      NaN     NaN     高松市    37201
# 3       香川県      NaN     NaN     高松市    37201
# 4       香川県      NaN     NaN     高松市    37201
# ..      ...      ...     ...     ...      ...
# 745     香川県      NaN    仲多度郡    多度津町    37404
# 746     香川県      NaN    仲多度郡    多度津町    37404
# 747     香川県      NaN    仲多度郡    多度津町    37404
# 748     香川県      NaN    仲多度郡    多度津町    37404
# 749     香川県      NaN    仲多度郡   まんのう町    37406
#
#                                               geometry
# 0    POLYGON ((134.05687 34.35148, 134.05687 34.351...
# 1    POLYGON ((134.05695 34.35742, 134.05674 34.356...
# 2    POLYGON ((134.05833 34.35984, 134.05757 34.359...
# 3    POLYGON ((134.05877 34.36048, 134.05875 34.360...
# 4    POLYGON ((134.07988 34.36148, 134.07986 34.361...
# ..                                                 ...
# ...

# %%
kagawa_ku['KEY_CODE'] = kagawa_ku['KEY_CODE'].astype(int)

# %%
kagawa_ku.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N03_001   750 non-null    object
#  1   N03_002   0 non-null      float64
#  2   N03_003   175 non-null    object
#  3   N03_004   750 non-null    object
#  4   KEY_CODE  750 non-null    int32
#  5   geometry  750 non-null    geometry
# dtypes: float64(1), geometry(1), int32(1), object(3)
# memory usage: 32.4+ KB

# %%
kagawa_ku_pop = kagawa_ku.merge(kagawa_pop,on='KEY_CODE')

# %%
kagawa_ku_pop
# Out:
#     N03_001  N03_002 N03_003 N03_004  KEY_CODE  \
# 0       香川県      NaN     NaN     高松市     37201
# 1       香川県      NaN     NaN     高松市     37201
# 2       香川県      NaN     NaN     高松市     37201
# 3       香川県      NaN     NaN     高松市     37201
# 4       香川県      NaN     NaN     高松市     37201
# ..      ...      ...     ...     ...       ...
# 745     香川県      NaN    仲多度郡    多度津町     37404
# 746     香川県      NaN    仲多度郡    多度津町     37404
# 747     香川県      NaN    仲多度郡    多度津町     37404
# 748     香川県      NaN    仲多度郡    多度津町     37404
# 749     香川県      NaN    仲多度郡   まんのう町     37406
#
#                                               geometry  HYOSYO CITYNAME NAME  \
# 0    POLYGON ((134.05687 34.35148, 134.05687 34.351...       1      高松市  NaN
# 1    POLYGON ((134.05695 34.35742, 134.05674 34.356...       1      高松市  NaN
# 2    POLYGON ((134.05833 34.35984, 134.05757 34.359...       1      高松市  NaN
# 3    POLYGON ((134.05877 34.36048, 134.05875 34.360...       1      高松市  NaN
# ...

# %%
kagawa_ku_pop['人口総数'] = kagawa_ku_pop['人口総数'].astype(int)

# %%
kagawa_ku_pop.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   N03_001   750 non-null    object
#  1   N03_002   0 non-null      float64
#  2   N03_003   175 non-null    object
#  3   N03_004   750 non-null    object
#  4   KEY_CODE  750 non-null    int32
#  5   geometry  750 non-null    geometry
#  6   HYOSYO    750 non-null    int64
#  7   CITYNAME  750 non-null    object
#  8   NAME      0 non-null      object
#  9   HTKSYORI  750 non-null    int64
#  10  HTKSAKI   0 non-null      float64
#  11  GASSAN    0 non-null      float64
#  12  人口総数      750 non-null    int32
#  13  男         750 non-null    object
#  14  女         750 non-null    object
#  15  世帯総数      750 non-null    object
# dtypes: float64(3), geometry(1), int32(2), int64(2), object(8)
# memory usage: 88.0+ KB

# %%
kagawa_ku_pop.plot(figsize=(10,10),
                  column='人口総数',
                  legend=True,
                  cmap='plasma')
# Out:
# <Axes: >
