# %%
import folium


kashiwaeki = [35.86238453604905, 139.97089573914457]


m = folium.Map(location=kashiwaeki, zoom_start=15)

oudouya=[35.86310705313056, 139.96749619209098]
folium.Marker(oudouya, popup="家系　", tooltip="王道家 柏店").add_to(m)

fukurou=[35.861254398368196, 139.9706365688336]
folium.Marker(fukurou, popup="二郎系　　", tooltip="ラーメン二九六").add_to(m)

akebi=[35.86090086608687, 139.9741098153531]
folium.Marker(akebi, popup="中華そば　　　", tooltip="AKEBI").add_to(m)

oremichi=[35.85572449449928, 139.97164485359403]
folium.Marker(oremichi, popup="二郎系　　", tooltip="俺の生きる道 柏店").add_to(m)

homare=[35.86054457043861, 139.969043470783]
folium.Marker(homare, popup="背脂系　　", tooltip="こってりラーメン誉").add_to(m)

daikatsu=[35.854602772556795, 139.97357127917732]
folium.Marker(daikatsu, popup="中華そば(煮干し)　　　　　　　", tooltip="大勝").add_to(m)

nishio=[35.86029125358195, 139.96834584466]
folium.Marker(nishio, popup="中華そば　　　", tooltip="麺処　にし尾").add_to(m)

teraccyo=[35.86058639460725, 139.97286167078306]
folium.Marker(teraccyo, popup="博多ラーメン　　　　　", tooltip="三代目てらッちょ").add_to(m)



m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8103b80d6f35459916e40eb6f4cba7f8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8103b80d6f35459916e40eb6f4cba7f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8103b80d6f35459916e40eb6f4cba7f8 = L.map(
#                 &quot;map_8103b80d6f35459916e40eb6f4cba7f8&quot;,
#                 {
#                     center: [35.86238453604905, 139.97089573914457],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e61082f78c3f1c0fadffdcec9becc59c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8103b80d6f35459916e40eb6f4cba7f8);
#
#
#             var marker_5a907dd7214ad21c66ea6a9dc5744949 = L.marker(
#                 [35.86310705313056, 139.96749619209098],
#                 {}
#             ).addTo(map_8103b80d6f35459916e40eb6f4cba7f8);
#
#
#         var popup_b290b9f42f5e0562224e6dee489227f2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b3770896810fa0df9aa1d4f2178bc75b = $(`&lt;div id=&quot;html_b3770896810fa0df9aa1d4f2178bc75b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;家系　&lt;/div&gt;`)[0];
#                 popup_b290b9f42f5e0562224e6dee489227f2.setContent(html_b3770896810fa0df9aa1d4f2178bc75b);
#
#
#
#         marker_5a907dd7214ad21c66ea6a9dc5744949.bindPopup(popup_b290b9f42f5e0562224e6dee489227f2)
#         ;
#
#
#
#
#             marker_5a907dd7214ad21c66ea6a9dc5744949.bindTooltip(
#                 `&lt;div&gt;
#                      王道家 柏店
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_09e4c0276af99002eeb68a4c12e9ff3e = L.marker(
#                 [35.861254398368196, 139.9706365688336],
#                 {}
#             ).addTo(map_8103b80d6f35459916e40eb6f4cba7f8);
#
#
#         var popup_e3452821e3f674192d15fff3ee901196 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_775615788547ad252fa7cd8f4bdc5a75 = $(`&lt;div id=&quot;html_775615788547ad252fa7cd8f4bdc5a75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;二郎系　　&lt;/div&gt;`)[0];
#                 popup_e3452821e3f674192d15fff3ee901196.setContent(html_775615788547ad252fa7cd8f4bdc5a75);
#
#
#
#         marker_09e4c0276af99002eeb68a4c12e9ff3e.bindPopup(popup_e3452821e3f674192d15fff3ee901196)
#         ;
#
#
#
#
#             marker_09e4c0276af99002eeb68a4c12e9ff3e.bindTooltip(
#                 `&lt;div&gt;
#                      ラーメン二九六
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b89302bfdb9228a2e7f68b3f623e6677 = L.marker(
#                 [35.86090086608687, 139.9741098153531],
#                 {}
#             ).addTo(map_8103b80d6f35459916e40eb6f4cba7f8);
#
#
#         var popup_614aa854df5e7ce87654fbfbc6b238c8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_91e378569eaaf16f02680a7c407535bc = $(`&lt;div id=&quot;html_91e378569eaaf16f02680a7c407535bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;中華そば　　　&lt;/div&gt;`)[0];
#                 popup_614aa854df5e7ce87654fbfbc6b238c8.setContent(html_91e378569eaaf16f02680a7c407535bc);
#
#
#
#         marker_b89302bfdb9228a2e7f68b3f623e6677.bindPopup(popup_614aa854df5e7ce87654fbfbc6b238c8)
#         ;
#
#
#
#
#             marker_b89302bfdb9228a2e7f68b3f623e6677.bindTooltip(
#                 `&lt;div&gt;
#                      AKEBI
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_342d0dbd59a23f6245d7f6b468e33365 = L.marker(
#                 [35.85572449449928, 139.97164485359403],
#                 {}
#             ).addTo(map_8103b80d6f35459916e40eb6f4cba7f8);
#
#
#         var popup_58997bdf1d8e664eae0eee2a1e323092 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3246258e3d1f85942222d49d8d103352 = $(`&lt;div id=&quot;html_3246258e3d1f85942222d49d8d103352&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;二郎系　　&lt;/div&gt;`)[0];
#                 popup_58997bdf1d8e664eae0eee2a1e323092.setContent(html_3246258e3d1f85942222d49d8d103352);
#
#
#
#         marker_342d0dbd59a23f6245d7f6b468e33365.bindPopup(popup_58997bdf1d8e664eae0eee2a1e323092)
#         ;
#
#
#
#
#             marker_342d0dbd59a23f6245d7f6b468e33365.bindTooltip(
#                 `&lt;div&gt;
#                      俺の生きる道 柏店
#                  &lt;/div&gt;`,
#                 {&quot;sticky

# %%
m.save('RamenMap.html')
