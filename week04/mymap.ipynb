# %%
import folium


kashiwaeki = [35.86238453604905, 139.97089573914457]


m = folium.Map(location=kashiwaeki, zoom_start=15)

folium.CircleMarker(
    location=[35.86238453604905, 139.97089573914457],
    radius=280,
    color='#ffff00',
    fill_color='#ffff00'
).add_to(m)
group_1 = folium.FeatureGroup("その他").add_to(m)
group_2 = folium.FeatureGroup("二郎系").add_to(m)
group_3 = folium.FeatureGroup("中華そば").add_to(m)

oudouya=[35.86310705313056, 139.96749619209098]
folium.Marker(oudouya, popup="家系　", tooltip="王道家 柏店",icon=folium.Icon(color='blue')).add_to(group_1)

fukurou=[35.861254398368196, 139.9706365688336]
folium.Marker(fukurou, popup="二郎系　　", tooltip="ラーメン二九六",icon=folium.Icon(color='green')).add_to(group_2)

akebi=[35.86090086608687, 139.9741098153531]
folium.Marker(akebi, popup="中華そば　　　", tooltip="AKEBI",icon=folium.Icon(color='red')).add_to(group_3)

oremichi=[35.85572449449928, 139.97164485359403]
folium.Marker(oremichi, popup="二郎系　　", tooltip="俺の生きる道 柏店",icon=folium.Icon(color='green')).add_to(group_2)

homare=[35.86054457043861, 139.969043470783]
folium.Marker(homare, popup="背脂系　　", tooltip="こってりラーメン誉",icon=folium.Icon(color='blue')).add_to(group_1)

daikatsu=[35.854602772556795, 139.97357127917732]
folium.Marker(daikatsu, popup="中華そば(煮干し)　　　　　　　", tooltip="大勝",icon=folium.Icon(color='red')).add_to(group_3)

nishio=[35.86029125358195, 139.96834584466]
folium.Marker(nishio, popup="中華そば　　　", tooltip="麺処　にし尾",icon=folium.Icon(color='red')).add_to(group_3)

teraccyo=[35.86058639460725, 139.97286167078306]
folium.Marker(teraccyo, popup="博多ラーメン　　　　　", tooltip="三代目てらッちょ",icon=folium.Icon(color='blue')).add_to(group_1)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94efbedbe3a2fd9370ea76048b9b10f6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94efbedbe3a2fd9370ea76048b9b10f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94efbedbe3a2fd9370ea76048b9b10f6 = L.map(
#                 &quot;map_94efbedbe3a2fd9370ea76048b9b10f6&quot;,
#                 {
#                     center: [35.86238453604905, 139.97089573914457],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_504a84f4308828fac344b5830a45f8ff = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_94efbedbe3a2fd9370ea76048b9b10f6);
#
#
#             var circle_marker_68225f0c6830378a6b9b23aa4f555d8f = L.circleMarker(
#                 [35.86238453604905, 139.97089573914457],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffff00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 280, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_94efbedbe3a2fd9370ea76048b9b10f6);
#
#
#             var feature_group_83f6fe7ec0e9adf99fe7dff90c15155c = L.featureGroup(
#                 {}
#             ).addTo(map_94efbedbe3a2fd9370ea76048b9b10f6);
#
#
#             var marker_68393373734a0d9fbe355853905e4404 = L.marker(
#                 [35.86310705313056, 139.96749619209098],
#                 {}
#             ).addTo(feature_group_83f6fe7ec0e9adf99fe7dff90c15155c);
#
#
#             var icon_06df3b263d9485e4f5e1033dbf5a1581 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_68393373734a0d9fbe355853905e4404.setIcon(icon_06df3b263d9485e4f5e1033dbf5a1581);
#
#
#         var popup_8b2c2263c0f51af2c3d999a754ca9d5a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ecf9a2f49bf1b5915cfd24445e4eb01b = $(`&lt;div id=&quot;html_ecf9a2f49bf1b5915cfd24445e4eb01b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;家系　&lt;/div&gt;`)[0];
#                 popup_8b2c2263c0f51af2c3d999a754ca9d5a.setContent(html_ecf9a2f49bf1b5915cfd24445e4eb01b);
#
#
#
#         marker_68393373734a0d9fbe355853905e4404.bindPopup(popup_8b2c2263c0f51af2c3d999a754ca9d5a)
#         ;
#
#
#
#
#             marker_68393373734a0d9fbe355853905e4404.bindTooltip(
#                 `&lt;div&gt;
#                      王道家 柏店
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4189332e82ee3d9f9027e3bac43fa61c = L.marker(
#                 [35.86054457043861, 139.969043470783],
#                 {}
#             ).addTo(feature_group_83f6fe7ec0e9adf99fe7dff90c15155c);
#
#
#             var icon_0e0193d8a77ca321f93d8a872d5462f8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4189332e82ee3d9f9027e3bac43fa61c.setIcon(icon_0e0193d8a77ca321f93d8a872d5462f8);
#
#
#         var popup_de96dfbaa2633b4ff3042fe658dc9bda = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_13a53ee3a24bc2864886e43991abcbf1 = $(`&lt;div id=&quot;html_13a53ee3a24bc2864886e43991abcbf1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;背脂系　　&lt;/div&gt;`)[0];
#                 popup_de96dfbaa2633b4ff3042fe658dc9bda.setContent(html_13a53ee3a24bc2864886e43991abcbf1);
#
#
#
#         marker_4189332e82ee3d9f9027e3bac43fa61c.bindPopup(popup_de96dfbaa2633b4ff3042fe658dc9bda)
#         ;
#
#
#
#
#             marker_4189332e82ee3d9f9027e3bac43fa61c.bindTooltip(
#                 `&lt;div&gt;
#                      こってりラーメン誉
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_109b03930820c69b0a60315d871b1446 = L.marker(
#                 [35.86058639460725, 139.97286167078306],
#                 {}
#             ).addTo(feature_group_83f6fe7ec0e9adf99fe7dff90c15155c);
#
#
#             var

# %%
m.save('RamenMap.html')
